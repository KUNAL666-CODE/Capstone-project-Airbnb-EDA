# %% [markdown]
# <a href="https://colab.research.google.com/github/KUNAL666-CODE/Capstone-project-Airbnb-EDA/blob/main/Airbnb_EDA_Kunal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Name**
#
# AirBnb Exploratory data analysis
#
#
# Contribution:Individual
#
# Team member name: **Kunal paunikar**

# %% [markdown]
# #**Project Summary**
#
# Since 2008 guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique,personalised way of experiencing the world.Today,Airbnb became one of a kind service that is used and recognized by the whole world.Data Analysis on millions of listings provided through airbnb is a crucial factor for the company.These millions of listings generate a lot of data -data that can be analysed and used for security,business decisions ,understanding of customers and providers behaviour and performance on the platform,guiding marketing initiatives ,implementation of innovative additional services and much more.
#
# This dataset has around 49000 observations in it with 16 columns and it is amix of categorical and numeric values.In this project weExplore and analyse the data to discover key understandings.

# %% [markdown]
# #**Github link** : https://github.com/KUNAL666-CODE/Capstone-project-Airbnb-EDA

# %% [markdown]
# #**Problem Statement**
#
# We need to evaluate the present day trends for accomodation booking via Airbnb ,airbnb has been a revolutionary technology driven company providing travellers accomodation while travelling at their finger tips ,they can book any accomodation online and it also provides its customers various options to review their stay after they checkout and share their feedback on its app and website. Our aim is to evaluate the dataset provided and derive conclusion and try to identify various trends which would help to take better decisions in respect of expanding the business and learn about various security concerns if any.

# %% [markdown]
# **lets begin**

# %%
#mounting the drive to access the dataset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importing libraries needed in the project

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Accessing the dataset

file_path="/content/drive/MyDrive/Airbnb NYC 2019.csv"  #assigning file path

airbnb_data_df=pd.read_csv(file_path) #creating a dataframe through the filepath

# %%
#having a look at the data

airbnb_data_df.info()  #info methid  prints information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
airbnb_data_df.describe()  #The describe() method returns description of the data in the DataFrame in terms of average,
                            #standard deviation and mean(for numerical values)
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
airbnb_data_df.head() #fetches the intial rows of the dataset
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb_data_df.shape #knowing the dimension of the dataset
                      #there are 448895 rows and 16 columns
# Out:
# (48895, 16)

# %%
airbnb_data_df.dtypes  #knowing data type of the columns
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
new_airbnb_df=airbnb_data_df.copy() #creating a copy so that the data remains intact

# %%
#cleaning the data and missing value handling

#checking for any duplicated values

airbnb_data_df.duplicated().sum()  #it seems there are no duplicated values
# Out:
# 0

# %%
#lets check for null values

airbnb_data_df.isnull().sum()

# it seems there are 16 null values in name and 21 null values in host_name ,also there are 10052 null values in last_revies and reviews_per_month
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#we can see that there are null values in last_review and reviews_per_month
#lets handle them first
#replacing null values with 0

airbnb_data_df.last_review.fillna(value=0,inplace=True)
airbnb_data_df.reviews_per_month.fillna(value=0,inplace=True)

# %%
#there are also null values in name and host-name colums which makes that data irrelevant
#lets drop that data

airbnb_data_df.dropna(subset=["name","host_name"],inplace=True)

# %%
airbnb_data_df.isnull().sum() #checking for null values again
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# **lets begin with the analysis**
#
# **Univariate analysis**

# %%
#let us first find the number of neighbourhood groups 

airbnb_data_df["neighbourhood_group"].nunique() 

#it seems that they are 5 neighbourhood group
#lets find what are they

airbnb_data_df["neighbourhood_group"].unique() 

#they are Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %% [markdown]
# **plot1**

# %%
#let us also find the types accomodations
airbnb_data_df["room_type"].unique() 

#there are three types of accomodation
#namely ['Private room', 'Entire home/apt', 'Shared room']
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
#let us now study the distribution of roomtype across neighbourhood group
# we can use countplot to study the count of various room types across the neighbourhood group   

plt.figure(figsize=(12,6))
sns.countplot(x="neighbourhood_group",data=airbnb_data_df,hue="room_type")
plt.show()

# %% [markdown]
# From the above plot we can infer that Manhattan has the maximum number of Entire home/apartment room_type whereas brooklyn has the maximum number of private room Brooklyn and Manhattan has maximum number of listings staten island and bronx have very few shared room

# %% [markdown]
# **plot2**

# %% [markdown]
# There are three types of accomodation namely 'Private room', 'Entire home/apt', 'Shared room'
#
# lets plot a countplot for the listings of the roomtype since we need to count the number of occasions during which the accomodations were booked we are using countplot

# %%
plt.figure(figsize=(12,6))
ax_2=sns.countplot(x="room_type",data=airbnb_data_df)
ax_2.set_title('frequency_plot')
ax_2.set_ylabel('count')
ax_2.set_xlabel('room_type')

plt.show()

# %% [markdown]
# we can see from the plot that the most listed roomtype is entire room apartment,followed by private room and shared room

# %% [markdown]
# **Bivariate** **Analysis**
#
# **plot3**
#
# Finding top 3 most expensive neighbourhood_group

# %%
# plotting Bar plot
#since we need to find categorical data we are using barplot

#finding top 3 most expensive neighbourhood_group
sns.set(rc={'figure.figsize':(12,10)})
ax_1=sns.barplot(x='neighbourhood_group',y='price',data=airbnb_data_df,hue="neighbourhood_group",errorbar=None)

# %% [markdown]
# From the above plot it is evident that the top 3 most expensive neighbourhoodgroup are Manhattan ,staten island and Brooklyn

# %% [markdown]
# Let us see how is the distribution of these roomtype across latitude and longitude
#
# latitude and logitude are parameters which are used to locate a particular location
# we can use scatter plot to study the concentration of various accomodation at a particular place
# scatterplot uses dots to represent values for two different numeric variables
# here we have two different numeric variables which are latitude and longitude which we can use to study the distribution of these roomtypes
#
# **plot4**

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="latitude",y="longitude",data=airbnb_data_df,hue="room_type")

plt.show()

# %% [markdown]
# we can see from the above plot that entire room and apartment as well as private room are densely located across longitude(-74.0 to -73.9) and latitude(40.6 to 40.9)

# %% [markdown]
# Let us study the relationship between roomtype and their availability 365 days
#
# **plot5**
#
# let us now plot a box plot to show the relationship betweeb various roomtypes and their availibility through out the year
# boxplots are used to show distribution of numeric data values

# %%
plt.figure(figsize=(12,6))
ax_3=sns.boxplot(x="availability_365",y="room_type",data=airbnb_data_df,hue="room_type")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# from the above plot we can see that shared room are mostly available 365 days hence few people prefer them

# %% [markdown]
# Let us find top 20 most reviewed properties. Most reviewed properties comes under the radar of most booked and most preferred accomodations therfore it is beneficial to know the most reviewed properties
#
# **plot6**

# %%
sorted_number_of_reviews=airbnb_data_df.sort_values(by="number_of_reviews",ascending=False)
top_20=sorted_number_of_reviews.head(20)
sns.boxenplot(x="neighbourhood_group",y="number_of_reviews",data=top_20,hue="room_type")
plt.show()

# %% [markdown]
# From the above plot it is evident that Queens had Manhattan have properties which are the most reviewed as well the properties which were reviewed are of private room type

# %% [markdown]
# Let us now find the properties where the number of nights are maximum and how the number of nights is affecting the prices of those accomodations
#
# **plot7**

# %%
sorted_minimum_nights=airbnb_data_df.sort_values(by="minimum_nights",ascending=False)
top_20_max_nights=sorted_minimum_nights.head(20)
#Here we are showing the relationship between minimum nights and pricing so let us use swarmplot

sns.swarmplot(x="minimum_nights",y="price",data=top_20_max_nights,hue="room_type")
plt.show()

# %% [markdown]
# From the above plot we can infer that pricing does not depend on minimum number of nights even if the minimum number of nights are high pricing might be low or vice versa

# %% [markdown]
# Let us now fetch the names of most busiest host ,the host which are reviewed the most are the most busiest host we already have top_20 maximuum reviews data lets plot the box plot on the basis of that data
#
# **plot8**

# %%
top_5_host_data=top_20.head(5)
sns.boxplot(x="host_name",y="number_of_reviews",data=top_5_host_data,hue="host_name")
# Out:
# <Axes: xlabel='host_name', ylabel='number_of_reviews'>

# %% [markdown]
# From the above plot it is evident that Dona and JJ are the hosts whose properties are among the top 5 most reviewed properties

# %% [markdown]
# Let us focus on the revenue that can be generated if all the accomodations of the neighbourhood group are booked
#
# **plot9**

# %%
location_revenue=airbnb_data_df.groupby(["neighbourhood_group"])["price"].sum().reset_index()

# %% [markdown]
# let us plot a pie chart for the above data

# %%
explode=(0,0,0.1,0,0)


data=location_revenue["price"]
keys=["Bronx","Brooklyn","Manhattan","Queens","Staten Island"]
plt.pie(data,labels=keys,explode=explode,autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f2ccabb93a0>,
# ...
#  [Text(1.0991157155562106, 0.044098115802829366, 'Bronx'),
#   Text(0.4669908377506956, 0.99595158389196, 'Brooklyn'),
#   Text(-0.8037385087707853, -0.8910692506864516, 'Manhattan'),
#   Text(1.0591462774322025, -0.2970002744131868, 'Queens'),
#   Text(1.0998212373267344, -0.01983042927148217, 'Staten Island')],
#  [Text(0.5995176630306602, 0.024053517710634197, '1%'),
#   Text(0.254722275136743, 0.5432463184865236, '33%'),
#   Text(-0.46884746344962475, -0.5197903962337634, '57%'),
#   Text(0.5777161513266558, -0.16200014967992007, '8%'),
#   Text(0.5999024930873096, -0.010816597784444819, '1%')])

# %% [markdown]
# From the above pie chart it is evident that Manhattan and Brooklyn are the most revenue generating neighbour_hood group

# %% [markdown]
# Let us now see that which neighbour_hood group consists of large number of nieghbourhood
#
# **plot10**

# %%
neighbourhood_data=airbnb_data_df.groupby(["neighbourhood_group"])["neighbourhood"].nunique().reset_index()

# %% [markdown]
# Now let us draw a pie chart for the above findings

# %%
explode=(0,0,0.1,0,0)
data_1=neighbourhood_data["neighbourhood"]
keys=["Bronx","Brooklyn","Manhattan","Queens","Staten Island"]
plt.pie(data_1,labels=keys,explode=explode,autopct='%.0f%%')
plt.show()

# %% [markdown]
# From the above data it is evident that queens has the maximum number of neighbourhood while manhattan has minimum numbers of neighbourhood

# %% [markdown]
# **Multivariate** **Analysis**
#
# Let us now plot heatmap of the airbnb daataset the heatmap shows the correlation between all the parameters of the dataset
#
# **plot11**

# %%
sns.heatmap(airbnb_data_df.corr(),cmap='RdBu_r', annot=True, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# Heatmap works on the priciple of relativity it has two concepts positive relativity and negative relativity positive relativity means when one variable increases other also increases whereas negative relativity means when one variable increase other decreases Also relativity closer to zero have very less relativity and relativity closer to 1 and -1 has more relativity. In the above heatmap every number shows relativity across various columns of the datasets Here we can see that reviews_per_month and number_of_reviews are positively relative and their relativity count is 0.59

# %% [markdown]
# Now let us study the variation in prices according to the room type using lmplot
#
# **plot12**

# %%
sns.lmplot(
    x="number_of_reviews", 
    y="price", 
    data=airbnb_data_df,
    palette='bright',
    col="room_type", 
    hue="room_type");

# %% [markdown]
# From the above plot it is evident that no matter what type of accomodation people book they mostly prefer accomodation whose prices are below 4000

# %% [markdown]
# #**Solution to Business Objective**
#
# **After analysing the dataset it is evident that people mostly prefer private home or private apartment so the company should focus more on promoting them ,although room sharing is an affordable option,people give priority to privacy.
# Secondly the company could offer discounts and promotional codes on less revenue generating localities which are Bronx ,Staten Islands and Queens,to promote them and increase listing from these localities.
# Pricing threshold is 4000 above this price there are very few bookings,people prefer paying around this price.

# %% [markdown]
# #**Conclusion and Findings**
#
#
# During EDA analysis we came to know about the following conclusions
#
# a) From the above plot we can infer that Manhattan has the maximum number of Entire home/apartment room_type whereas brooklyn has the maximum number of private room Brooklyn and Manhattan has maximum number of listings staten island and bronx have very few shared room(Reference plot 1(Bar plot))
#
# b)The most listed roomtype is entire room apartment,followed by private room and shared room(Reference plot2)
#
# c)From the above plot it is evident that the top 3 most expensive neighbourhoodgroup are Manhattan ,staten island and Brooklyn(Reference plot3)
#
# d)Entire room and apartment as well as private room are densely located across longitude(-74.0 to -73.9) and latitude(40.6 to 40.9)(Reference plot4)
#
# d)Shared room are mostly available 365 days hence few people prefer them(Reference plot5)
#
# f) Queens had Manhattan have properties which are the most reviewed as well the properties which were reviewed are of private room type(Reference plot6)
#
# g)Pricing does not depend on minimum number of nights even if the minimum number of nights are high pricing might be low or vice versa (plot7)
#
# h)Dona and JJ are the hosts whose properties are among the top 5 most reviewed properties(Reference plot8)
#
# i)Manhattan and Brooklyn are the most revenue generating neighbour_hood group(Reference plot9)
#
# j)Queens has the maximum number of neighbourhood while manhattan has minimum numbers of neighbourhood(Reference plot 10)
#
# k)Reviews_per_month and number_of_reviews are positively relative and their relativity count is 0.59(Reference plot11)
#
# l)No matter what type of accomodation people book they mostly prefer accomodation whose prices are below 4000(Reference plot12)
